# %% [markdown]
# # Stock Market Analysis Project
#
#
#
#
# ### Part 0: Import
#
# ** Import the various libraries you will need-you can always just come back up here or import as you go along :) **

# %%
import numpy as ny
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ____
# ## Part 1: Getting the Data
#
# ### PCAR Stock (Ticker: PCAR on the NASDAQ)

# %%
PCAR=pd.read_csv('PCAR.csv',index_col='Date',parse_dates=True)

# %%
PCAR.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-05-01  63.730000  64.430000  63.700001  64.089996  51.086945  1680600
# 2014-05-02  64.459999  64.519997  63.150002  63.290001  50.449265  2212900
# 2014-05-05  62.660000  63.689999  62.520000  63.380001  50.521000  1973700
# 2014-05-06  63.080002  63.480000  62.560001  62.740002  50.010849  1267800
# 2014-05-07  62.700001  63.180000  62.169998  62.880001  50.122429  1218200

# %% [markdown]
# ### Other Car Companies
#
# ** Repeat the same steps to grab data for Ford and GM (General Motors), **

# %%
CNHI=pd.read_csv('CNHI.csv',index_col='Date',parse_dates=True)
CAT=pd.read_csv("CAT.csv",index_col='Date',parse_dates=True)
NAV=pd.read_csv("NAV.csv",index_col='Date',parse_dates=True)
OSK=pd.read_csv("OSK.csv",index_col='Date',parse_dates=True)
TEX=pd.read_csv("TEX.csv",index_col='Date',parse_dates=True)
WNC=pd.read_csv("WNC.csv",index_col='Date',parse_dates=True)

# %%
CNHI.head()
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2014-05-01  11.57  11.66  11.54  11.63  10.639881  537900
# 2014-05-02  11.60  11.67  11.56  11.62  10.630731  465900
# 2014-05-05  11.33  11.47  11.25  11.43  10.456908  559800
# 2014-05-06  11.35  11.51  11.33  11.47  10.493504  518300
# 2014-05-07  11.48  11.63  11.40  11.60  10.612434  775200

# %%
CAT.head()
# Out:
#                   Open        High         Low       Close  Adj Close   Volume
# Date
# 2014-05-01  105.199997  105.790001  104.629997  105.070000  86.817627  2970800
# 2014-05-02  104.930000  105.580002  104.730003  105.010002  86.768005  2677000
# 2014-05-05  104.660004  104.800003  103.809998  104.519997  86.363144  3166400
# 2014-05-06  104.209999  104.470001  103.599998  103.870003  85.826057  2836300
# 2014-05-07  104.099998  104.660004  103.430000  104.620003  86.445763  3399800

# %%
NAV.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-05-01  37.790001  38.560001  37.689999  38.049999  38.049999  1042200
# 2014-05-02  38.090000  38.470001  37.130001  37.259998  37.259998  1078700
# 2014-05-05  37.060001  37.160000  36.320000  36.450001  36.450001   906900
# 2014-05-06  36.290001  36.500000  35.250000  35.340000  35.340000   782300
# 2014-05-07  35.459999  35.689999  34.330002  34.570000  34.570000  1156200

# %%
OSK.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2014-05-01  55.410000  55.889999  54.669998  54.939999  50.613071  779700
# 2014-05-02  54.790001  55.820000  54.619999  55.099998  50.760464  720200
# 2014-05-05  55.000000  55.310001  54.250000  55.230000  50.880226  929000
# 2014-05-06  54.849998  55.360001  54.400002  54.869999  50.548580  694100
# 2014-05-07  54.910000  55.320000  53.990002  54.759998  50.447247  460400

# %%
TEX.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-05-01  42.060001  44.680000  42.060001  42.820000  40.266346  3245300
# 2014-05-02  42.990002  42.990002  40.590000  40.869999  38.432644  3275400
# 2014-05-05  40.200001  40.709999  39.630001  40.230000  37.830803  2050600
# 2014-05-06  39.950001  40.430000  39.560001  39.810001  37.435867  1661000
# 2014-05-07  39.910000  39.939999  39.099998  39.910000  37.529892  2193900

# %%
WNC.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2014-05-01  13.30  13.62  13.16  13.45  12.723470  1111800
# 2014-05-02  13.45  13.77  13.40  13.64  12.903205  1045400
# 2014-05-05  13.51  13.51  13.14  13.31  12.591033   805500
# 2014-05-06  13.24  13.35  13.04  13.13  12.420756   827100
# 2014-05-07  13.16  13.28  12.86  13.22  12.505894   707600

# %% [markdown]
# ## Part 2: Visualizing the Data
#
# ** Time to visualize the data. **
#
# ** Follow along and recreate the plots below according to the instructions and explanations. **

# %% [markdown]
# ____
#
# ** Recreate this linear plot of all the stocks' Open price ! Hint: For the legend, use label parameter and plt.legend()**

# %%
# Code Here

CNHI['Open'].plot(label='CNHI',figsize=(16,8),title='Open price')
CAT['Open'].plot(label='CAT')
NAV['Open'].plot(label='NAV')
OSK['Open'].plot(label='OSK')
TEX['Open'].plot(label='TEX')
WNC['Open'].plot(label='WNC')
PCAR['Open'].plot(label='PCAR')
plt.legend()

# %% [markdown]
# ____

# %% [markdown]
# ** Plot the Volume of stock traded each day.**

# %%
CNHI['Volume'].plot(label='CNHI',figsize=(16,8),title='Volume Traded')
CAT['Volume'].plot(label='CAT')
NAV['Volume'].plot(label='NAV')
OSK['Volume'].plot(label='OSK')
TEX['Volume'].plot(label='TEX')
WNC['Volume'].plot(label='WNC')
PCAR['Volume'].plot(label='PCAR')
plt.legend()

# %% [markdown]
# ** Interesting, looks like CAT had a really big spike somewhere in late 2015. What was the date of this maximum trading volume for CAT?**
#
# **Bonus: What happened that day? **

# %%
CAT['Volume'].argmax()
# Out:
# C:\Users\jiwei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# Timestamp('2015-01-27 00:00:00')

# %% [markdown]
# ____

# %% [markdown]
# ** The Open Price Time Series Visualization makes CAT look like its always been much more valuable as a company than PCAR and NAV. But to really understand this we would need to look at the total market cap of the company, not just the stock price. Unfortunately our current data doesn't have that information of total units of stock present. But what we can do as a simple calcualtion to try to represent total money traded would be to multply the Volume column by the Open price. Remember that this still isn't the actual Market Cap, its just a visual representation of the total amount of money being traded around using the time series. (e.g. 100 units of stock at \$10 each versus 100000 units of stock at $1 each)**

# %% [markdown]
# ** Create a new column for each dataframe called "Total Traded" which is the Open Price multiplied by the Volume Traded.**

# %%
# Code Here 

CNHI['Total Traded']=CNHI['Open']*CNHI['Volume']
CAT['Total Traded']=CAT['Open']*CAT['Volume']
NAV['Total Traded']=NAV['Open']*NAV['Volume']
OSK['Total Traded']=OSK['Open']*OSK['Volume']
TEX['Total Traded']=TEX['Open']*TEX['Volume']
WNC['Total Traded']=WNC['Open']*WNC['Volume']
PCAR['Total Traded']=PCAR['Open']*PCAR['Volume']

# %% [markdown]
# ** Plot this "Total Traded" against the time index.**

# %%
# Code here



CNHI['Total Traded'].plot(label='CNHI',figsize=(16,8),title='Volume Traded')
CAT['Total Traded'].plot(label='CAT')
NAV['Total Traded'].plot(label='NAV')
OSK['Total Traded'].plot(label='OSK')
TEX['Total Traded'].plot(label='TEX')
WNC['Total Traded'].plot(label='WNC')
PCAR['Total Traded'].plot(label='PCAR')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %% [markdown]
# ** Interesting, looks like there was huge amount of money traded for Tesla somewhere in early 2014. What date was that and what happened? **

# %%
CAT['Total Traded'].argmax()
# Out:
# C:\Users\jiwei\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# Timestamp('2018-04-24 00:00:00')

# %% [markdown]
# ____

# %% [markdown]
# ** Let's practice plotting out some MA (Moving Averages). Plot out the MA50 and MA200 for CAT. **

# %%
# Code here

CAT['MA50']=CAT['Open'].rolling(50).mean()
CAT['MA200']=CAT['Open'].rolling(200).mean()
CAT[['Open','MA50','MA200']].plot(figsize=(16,8))

# %% [markdown]
# ______

# %% [markdown]
# ** Finally lets see if there is a relationship between these stocks, after all, they are all related to the car industry. We can see this easily through a scatter matrix plot. Import scatter_matrix from pandas.plotting and use it to create a scatter matrix plot of all the stocks'opening price.

# %%
from pandas.plotting import scatter_matrix

# %%
car_comp=pd.concat([CNHI['Open'],CAT['Open'],NAV['Open'],OSK['Open'],TEX['Open'],WNC['Open'],PCAR['Open']],axis=1)

# %%
car_comp.columns=['CNHI','CAT','NAV','OSK','TEX','WNC','PCAR']

# %%
scatter_matrix(car_comp,figsize=(16,8),alpha=0.2,hist_kwds={'bins':50});

# %% [markdown]
# ____
# # Part 3: Basic Financial Analysis
#
# ____

# %% [markdown]
# ## Daily Percentage Change
# First we will begin by calculating the daily percentage change. Daily percentage change is defined by the following formula:

# %% [markdown]
# $ r_t = \frac{p_t}{p_{t-1}} -1$

# %% [markdown]
# This defines r_t (return at time t) as equal to the price at time t divided by the price at time t-1 (the previous day) minus 1. Basically this just informs you of your percent gain (or loss) if you bought the stock on day and then sold it the next day. While this isn't necessarily helpful for attempting to predict future values of the stock, its very helpful in analyzing the volatility of the stock. If daily returns have a wide distribution, the stock is more volatile from one day to the next. Let's calculate the percent returns and then plot them with a histogram, and decide which stock is the most stable!

# %% [markdown]
# ** Create a new column for each dataframe called returns. This column will be calculated from the Close price column. There are two ways to do this, either a simple calculation using the .shift() method that follows the formula above, or you can also use pandas' built in pct_change method. **

# %%
CAT['returns']=(CAT['Close']/CAT['Close'].shift(1)-1)

# %%
CAT.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2014-05-01  105.199997  105.790001  104.629997  105.070000  86.817627
# 2014-05-02  104.930000  105.580002  104.730003  105.010002  86.768005
# 2014-05-05  104.660004  104.800003  103.809998  104.519997  86.363144
# 2014-05-06  104.209999  104.470001  103.599998  103.870003  85.826057
# 2014-05-07  104.099998  104.660004  103.430000  104.620003  86.445763
#
#              Volume  Total Traded  MA50  MA200   returns
# Date
# 2014-05-01  2970800  3.125282e+08   NaN    NaN       NaN
# 2014-05-02  2677000  2.808976e+08   NaN    NaN -0.000571
# 2014-05-05  3166400  3.313954e+08   NaN    NaN -0.004666
# 2014-05-06  2836300  2.955708e+08   NaN    NaN -0.006219
# 2014-05-07  3399800  3.539192e+08   NaN    NaN  0.007221

# %%
CAT['returns']=CAT['Close'].pct_change(1)
CAT.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2014-05-01  105.199997  105.790001  104.629997  105.070000  86.817627
# 2014-05-02  104.930000  105.580002  104.730003  105.010002  86.768005
# 2014-05-05  104.660004  104.800003  103.809998  104.519997  86.363144
# 2014-05-06  104.209999  104.470001  103.599998  103.870003  85.826057
# 2014-05-07  104.099998  104.660004  103.430000  104.620003  86.445763
#
#              Volume  Total Traded  MA50  MA200   returns
# Date
# 2014-05-01  2970800  3.125282e+08   NaN    NaN       NaN
# 2014-05-02  2677000  2.808976e+08   NaN    NaN -0.000571
# 2014-05-05  3166400  3.313954e+08   NaN    NaN -0.004666
# 2014-05-06  2836300  2.955708e+08   NaN    NaN -0.006219
# 2014-05-07  3399800  3.539192e+08   NaN    NaN  0.007221

# %%
NAV['returns']=NAV['Close'].pct_change(1)
CNHI['returns']=CNHI['Close'].pct_change(1)
OSK['returns']=OSK['Close'].pct_change(1)
TEX['returns']=TEX['Close'].pct_change(1)
WNC['returns']=WNC['Close'].pct_change(1)
PCAR['returns']=PCAR['Close'].pct_change(1)

# %%
NAV.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2014-05-01  37.790001  38.560001  37.689999  38.049999  38.049999  1042200
# 2014-05-02  38.090000  38.470001  37.130001  37.259998  37.259998  1078700
# 2014-05-05  37.060001  37.160000  36.320000  36.450001  36.450001   906900
# 2014-05-06  36.290001  36.500000  35.250000  35.340000  35.340000   782300
# 2014-05-07  35.459999  35.689999  34.330002  34.570000  34.570000  1156200
#
#             Total Traded   returns
# Date
# 2014-05-01  3.938474e+07       NaN
# 2014-05-02  4.108768e+07 -0.020762
# 2014-05-05  3.360971e+07 -0.021739
# 2014-05-06  2.838967e+07 -0.030453
# 2014-05-07  4.099885e+07 -0.021788

# %%
CNHI.head()
# Out:
#              Open   High    Low  Close  Adj Close  Volume  Total Traded  \
# Date
# 2014-05-01  11.57  11.66  11.54  11.63  10.639881  537900     6223503.0
# 2014-05-02  11.60  11.67  11.56  11.62  10.630731  465900     5404440.0
# 2014-05-05  11.33  11.47  11.25  11.43  10.456908  559800     6342534.0
# 2014-05-06  11.35  11.51  11.33  11.47  10.493504  518300     5882705.0
# 2014-05-07  11.48  11.63  11.40  11.60  10.612434  775200     8899296.0
#
#              returns
# Date
# 2014-05-01       NaN
# 2014-05-02 -0.000860
# 2014-05-05 -0.016351
# 2014-05-06  0.003500
# 2014-05-07  0.011334

# %%
OSK.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2014-05-01  55.410000  55.889999  54.669998  54.939999  50.613071  779700
# 2014-05-02  54.790001  55.820000  54.619999  55.099998  50.760464  720200
# 2014-05-05  55.000000  55.310001  54.250000  55.230000  50.880226  929000
# 2014-05-06  54.849998  55.360001  54.400002  54.869999  50.548580  694100
# 2014-05-07  54.910000  55.320000  53.990002  54.759998  50.447247  460400
#
#             Total Traded   returns
# Date
# 2014-05-01  4.320318e+07       NaN
# 2014-05-02  3.945976e+07  0.002912
# 2014-05-05  5.109500e+07  0.002359
# 2014-05-06  3.807138e+07 -0.006518
# 2014-05-07  2.528056e+07 -0.002005

# %%
TEX.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2014-05-01  42.060001  44.680000  42.060001  42.820000  40.266346  3245300
# 2014-05-02  42.990002  42.990002  40.590000  40.869999  38.432644  3275400
# 2014-05-05  40.200001  40.709999  39.630001  40.230000  37.830803  2050600
# 2014-05-06  39.950001  40.430000  39.560001  39.810001  37.435867  1661000
# 2014-05-07  39.910000  39.939999  39.099998  39.910000  37.529892  2193900
#
#             Total Traded   returns
# Date
# 2014-05-01  1.364973e+08       NaN
# 2014-05-02  1.408095e+08 -0.045539
# 2014-05-05  8.243412e+07 -0.015659
# 2014-05-06  6.635695e+07 -0.010440
# 2014-05-07  8.755855e+07  0.002512

# %%
WNC.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume  Total Traded  \
# Date
# 2014-05-01  13.30  13.62  13.16  13.45  12.723470  1111800    14786940.0
# 2014-05-02  13.45  13.77  13.40  13.64  12.903205  1045400    14060630.0
# 2014-05-05  13.51  13.51  13.14  13.31  12.591033   805500    10882305.0
# 2014-05-06  13.24  13.35  13.04  13.13  12.420756   827100    10950804.0
# 2014-05-07  13.16  13.28  12.86  13.22  12.505894   707600     9312016.0
#
#              returns
# Date
# 2014-05-01       NaN
# 2014-05-02  0.014126
# 2014-05-05 -0.024194
# 2014-05-06 -0.013524
# 2014-05-07  0.006855

# %%
PCAR.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2014-05-01  63.730000  64.430000  63.700001  64.089996  51.086945  1680600
# 2014-05-02  64.459999  64.519997  63.150002  63.290001  50.449265  2212900
# 2014-05-05  62.660000  63.689999  62.520000  63.380001  50.521000  1973700
# 2014-05-06  63.080002  63.480000  62.560001  62.740002  50.010849  1267800
# 2014-05-07  62.700001  63.180000  62.169998  62.880001  50.122429  1218200
#
#             Total Traded   returns
# Date
# 2014-05-01  1.071046e+08       NaN
# 2014-05-02  1.426435e+08 -0.012482
# 2014-05-05  1.236720e+08  0.001422
# 2014-05-06  7.997283e+07 -0.010098
# 2014-05-07  7.638114e+07  0.002231

# %% [markdown]
# ** Now plot a histogram of each companies returns. Either do them separately, or stack them on top of each other. Which stock is the most "volatile"? (as judged by the variance in the daily returns we will discuss volatility in a lot more detail in future lectures.)**

# %%
CAT['returns'].hist(bins=50)

# %%
NAV['returns'].hist(bins=50)

# %%
CNHI['returns'].hist(bins=50)

# %%
OSK['returns'].hist(bins=50)

# %%
TEX['returns'].hist(bins=50)

# %%
WNC['returns'].hist(bins=50)

# %%
PCAR['returns'].hist(bins=50)

# %%
CAT['returns'].hist(bins=100,label='CAT',figsize=(10,8),alpha=0.5)
NAV['returns'].hist(bins=100,label='NAV',alpha=0.5)
CNHI['returns'].hist(bins=100,label='CNHI',alpha=0.5)
OSK['returns'].hist(bins=100,label='OSK',alpha=0.5)
TEX['returns'].hist(bins=100,label='TEX',alpha=0.5)
WNC['returns'].hist(bins=100,label='WNC',alpha=0.5)
PCAR['returns'].hist(bins=100,label='PCAR',alpha=0.5)
plt.legend()

# %% [markdown]
# ** Try also plotting a KDE instead of histograms for another view point. Which stock has the widest plot? **

# %%
CAT['returns'].plot(kind='kde',label='CAT',figsize=(12,6))
NAV['returns'].plot(kind='kde',label='NAV')
CNHI['returns'].plot(kind='kde',label='CNHI')
OSK['returns'].plot(kind='kde',label='OSK')
TEX['returns'].plot(kind='kde',label='TEX')
WNC['returns'].plot(kind='kde',label='WNC')
PCAR['returns'].plot(kind='kde',label='PCAR')
plt.legend()

# %% [markdown]
# ** Try also creating some box plots comparing the returns. **

# %%
box_plot=pd.concat([CAT['returns'],NAV['returns'],CNHI['returns'],OSK['returns'],TEX['returns'],WNC['returns'],PCAR['returns']],axis=1)
box_plot.columns=['CAT returns','NAV returns','CNHI returns','OSK returns','TEX returns','WNC returns','PCAR returns']
box_plot.plot(kind='box',figsize=(8,11),colormap='jet')

# %% [markdown]
# ## Comparing Daily Returns between Stocks
#
# ** Create a scatter matrix plot to see the correlation between each of the stocks daily returns. This helps answer the questions of how related the car companies are. Is CAT begin treated more as a technology company rather than a car company by the market?**

# %%
scatter_matrix(box_plot,alpha=0.2, hist_kwds={'bins':50},figsize=(10,10));

# %% [markdown]
# ** It looks like CAT and PCAR do have some sort of possible relationship, let's plot just these two against eachother in scatter plot to view this more closely!**

# %%
box_plot.plot(kind='scatter',figsize=(10,8),alpha=0.4,x='CAT returns',y='PCAR returns')

# %% [markdown]
# ____
# ## Cumulative Daily Returns
#
# Great! Now we can see which stock was the most wide ranging in daily returns (you should have realized it was Tesla, our original stock price plot should have also made that obvious).
#
# With daily cumulative returns, the question we are trying to answer is the following, if I invested $1 in the company at the beginning of the time series, how much would is be worth today? This is different than just the stock price at the current day, because it will take into account the daily returns. Keep in mind, our simple calculation here won't take into account stocks that give back a dividend. Let's look at some simple examples:

# %% [markdown]
# Lets us say there is a stock 'ABC' that is being actively traded on an exchange. ABC has the following prices corresponding to the dates given

# %% [markdown]
#     Date                        Price
#     01/01/2018                   10
#     01/02/2018                   15
#     01/03/2018                   20
#     01/04/2018                   25

# %% [markdown]
# **Daily Return** : Daily return is the profit/loss made by the stock compared to the previous day. (This is what ew just calculated above). A value above one indicates profit, similarly a value below one indicates loss. It is also expressed in percentage to convey the information better. (When expressed as percentage, if the value is above 0, the stock had give you profit else loss). So for the above example the daily returns would be

# %% [markdown]
#     Date                         Daily Return                  %Daily Return
#     01/01/2018                 10/10 =  1                          -
#     01/02/2018                 15/10 =  3/2                       50%
#     01/03/2018                 20/15 =  4/3                       33%
#     01/04/2018                 25/20 =  5/4                       20%

# %% [markdown]
# **Cumulative Return**: While daily returns are useful, it doesn't give the investor a immediate insight into the gains he had made till date, especially if the stock is very volatile. Cumulative return is computed relative to the day investment is made.  If cumulative return is above one, you are making profits else you are in loss. So for the above example cumulative gains are as follows

# %% [markdown]
#     Date                       Cumulative Return         %Cumulative Return
#     01/01/2018                  10/10 =  1                         100 %
#     01/02/2018                  15/10 =  3/2                       150 %
#     01/03/2018                  20/10 =  2                         200 %
#     01/04/2018                  25/10 =  5/2                       250 %

# %% [markdown]
# The formula for a cumulative daily return is:
#
# $ i_i = (1+r_t) * i_{t-1} $
#
# Here we can see we are just multiplying our previous investment at i at t-1 by 1+our percent returns. Pandas makes this very simple to calculate with its cumprod() method. Using something in the following manner:
#
#     df[daily_cumulative_return] = ( 1 + df[pct_daily_return] ).cumprod()

# %% [markdown]
# ** Create a cumulative daily return column for each car company's dataframe.**

# %%
CAT['Cumulative Return']=(1+CAT['returns']).cumprod()
CAT.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2014-05-01  105.199997  105.790001  104.629997  105.070000  86.817627
# 2014-05-02  104.930000  105.580002  104.730003  105.010002  86.768005
# 2014-05-05  104.660004  104.800003  103.809998  104.519997  86.363144
# 2014-05-06  104.209999  104.470001  103.599998  103.870003  85.826057
# 2014-05-07  104.099998  104.660004  103.430000  104.620003  86.445763
#
#              Volume  Total Traded  MA50  MA200   returns  Cumulative Return
# Date
# 2014-05-01  2970800  3.125282e+08   NaN    NaN       NaN                NaN
# 2014-05-02  2677000  2.808976e+08   NaN    NaN -0.000571           0.999429
# 2014-05-05  3166400  3.313954e+08   NaN    NaN -0.004666           0.994765
# 2014-05-06  2836300  2.955708e+08   NaN    NaN -0.006219           0.988579
# 2014-05-07  3399800  3.539192e+08   NaN    NaN  0.007221           0.995717

# %%
NAV['Cumulative Return']=(1+NAV['returns']).cumprod()
CNHI['Cumulative Return']=(1+CNHI['returns']).cumprod()
OSK['Cumulative Return']=(1+OSK['returns']).cumprod()
TEX['Cumulative Return']=(1+TEX['returns']).cumprod()
WNC['Cumulative Return']=(1+WNC['returns']).cumprod()
PCAR['Cumulative Return']=(1+PCAR['returns']).cumprod()

# %% [markdown]
# ** Now plot the Cumulative Return columns against the time series index. Which stock showed the highest return for a $1 invested? Which showed the lowest?**

# %%
CAT['Cumulative Return'].plot(figsize=(16,8),label='CAT')
NAV['Cumulative Return'].plot(label='NAV')
CNHI['Cumulative Return'].plot(label='CNHI')
OSK['Cumulative Return'].plot(label='OSK')
TEX['Cumulative Return'].plot(label='TEX')
WNC['Cumulative Return'].plot(label='WNC')
PCAR['Cumulative Return'].plot(label='PCAR')
plt.legend()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Settings to produce nice plots in a Jupyter notebook
plt.style.use('fivethirtyeight')
# %matplotlib inline

# Reading in the data
stock_data = pd.read_csv('stock_data.csv', parse_dates =['Date'], index_col = ['Date']).dropna()
benchmark_data = pd.read_csv('Benchmark.csv', parse_dates =['Date'], index_col = ['Date']).dropna()

# %%
# Display summary for stock_data
print('Stocks\n')
# ... YOUR CODE FOR TASK 2 HERE ...
stock_data.info()
# Display summary for benchmark_data
print('\nBenchmarks\n')
# ... YOUR CODE FOR TASK 2 HERE ...
benchmark_data.head()
# Out:
# Stocks
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2014-05-01 to 2019-04-30
# Data columns (total 7 columns):
# CAT     1258 non-null float64
# CNHI    1258 non-null float64
# NAV     1258 non-null float64
# OSK     1258 non-null float64
# PCAR    1258 non-null float64
# TEX     1258 non-null float64
# WNC     1258 non-null float64
# dtypes: float64(7)
# memory usage: 78.6 KB
#
# Benchmarks
#                  S&P500
# Date
# 2014-05-01  1884.390015
# 2014-05-02  1885.300049
# 2014-05-05  1879.449951
# 2014-05-06  1883.689941
# 2014-05-07  1868.530029

# %%
# visualize the stock_data
# ... YOUR CODE FOR TASK 3 HERE ...
stock_data.plot(subplots = True, title = 'Stock Data')

# summarize the stock_data
# ... YOUR CODE FOR TASK 3 HERE ...
stock_data.describe()
# Out:
#                CAT         CNHI          NAV          OSK         PCAR  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    105.550175     9.514531    28.549515    59.694046    62.681582
# std      28.157392     2.128394    10.370838    15.882152     6.366752
# min      58.080000     5.820000     5.960000    30.310000    44.280000
# 25%      82.577500     7.670000    22.330000    46.140000    58.342500
# 50%      99.720000     9.280000    30.180000    55.870000    63.940000
# 75%     131.322500    11.237500    36.907500    71.797500    67.330000
# max     173.100000    15.370000    47.080000    98.710000    78.410000
#
#                TEX          WNC
# count  1258.000000  1258.000000
# mean     31.443196    15.817949
# std       8.168005     3.813681
# min      14.300000     9.690000
# 25%      24.322500    12.992500
# 50%      31.090000    14.195000
# 75%      38.425000    19.832500
# max      49.730000    26.020000

# %%
# plot the benchmark_data
# ... YOUR CODE FOR TASK 4 HERE ...
benchmark_data['S&P500'].plot(title = "S&P 500")

# summarize the benchmark_data
# ... YOUR CODE FOR TASK 4 HERE ...
benchmark_data.describe()
# Out:
#             S&P500
# count  1258.000000
# mean   2315.952718
# std     317.622915
# min    1833.400024
# 25%    2057.605042
# 50%    2178.290039
# 75%    2634.672425
# max    2940.580078

# %%
# calculate daily stock_data returns
stock_returns = stock_data.pct_change()

# plot the daily returns
# ... YOUR CODE FOR TASK 5 HERE ...
stock_returns.plot(figsize=(16,8),alpha=0.5)

# summarize the daily returns
# ... YOUR CODE FOR TASK 5 HERE ...
stock_returns.describe()
# Out:
#                CAT         CNHI          NAV          OSK         PCAR  \
# count  1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean      0.000372     0.000154     0.000531     0.000547     0.000216
# std       0.017001     0.019960     0.035137     0.022247     0.015423
# min      -0.099656    -0.102960    -0.172840    -0.154063    -0.089776
# 25%      -0.008368    -0.011429    -0.016842    -0.009788    -0.007765
# 50%       0.000961     0.000000     0.000671     0.000670    -0.000312
# 75%       0.008953     0.011123     0.016954     0.011171     0.008093
# max       0.090965     0.089076     0.430029     0.186970     0.095829
#
#                TEX          WNC
# count  1257.000000  1257.000000
# mean      0.000212     0.000371
# std       0.028577     0.023698
# min      -0.213128    -0.227893
# 25%      -0.012899    -0.012205
# 50%       0.000789     0.000000
# 75%       0.013844     0.012204
# max       0.357052     0.146589

# %%
# calculate daily benchmark_data returns
# ... YOUR CODE FOR TASK 6 HERE ...
sp_returns = benchmark_data['S&P500'].pct_change()

# plot the daily returns
# ... YOUR CODE FOR TASK 6 HERE ...
sp_returns.plot(figsize=(16,8))

# summarize the daily returns
# ... YOUR CODE FOR TASK 6 HERE ...
sp_returns.describe()
# Out:
# count    1257.000000
# mean        0.000384
# std         0.007823
# min        -0.046070
# 25%        -0.003014
# 50%         0.000693
# 75%         0.004261
# max         0.037389
# Name: S&P500, dtype: float64

# %%
# calculate the difference in daily returns
excess_returns = stock_returns.sub(sp_returns, axis =0)

# plot the excess_returns
# ... YOUR CODE FOR TASK 7 HERE ...
excess_returns.plot(figsize=(16,8))

# summarize the excess_returns
# ... YOUR CODE FOR TASK 7 HERE ...
excess_returns.describe()
# Out:
#                CAT         CNHI          NAV          OSK         PCAR  \
# count  1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean     -0.000012    -0.000230     0.000148     0.000163    -0.000168
# std       0.014293     0.018628     0.032941     0.020491     0.013160
# min      -0.082541    -0.108221    -0.171742    -0.120176    -0.062332
# 25%      -0.007605    -0.010985    -0.015476    -0.009215    -0.006908
# 50%       0.000085    -0.000426     0.000308     0.000490    -0.000537
# 75%       0.006992     0.009796     0.015010     0.009241     0.006194
# max       0.081470     0.089470     0.428137     0.221099     0.084862
#
#                TEX          WNC
# count  1257.000000  1257.000000
# mean     -0.000171    -0.000012
# std       0.026578     0.021962
# min      -0.212468    -0.225614
# 25%      -0.012002    -0.010801
# 50%       0.000119    -0.000679
# 75%       0.011954     0.009639
# max       0.344422     0.143453

# %%
# calculate the mean of excess_returns 
# ... YOUR CODE FOR TASK 8 HERE ...
avg_excess_return = excess_returns.mean()

# plot avg_excess_returns
# ... YOUR CODE FOR TASK 8 HERE ...
avg_excess_return.plot.bar(title = 'Mean of the Return Difference')

# %%
# calculate the standard deviations
sd_excess_return = excess_returns.std()

# plot the standard deviations
# ... YOUR CODE FOR TASK 9 HERE ...
sd_excess_return.plot.bar(title = 'Deviation of the Return Difference')

# %%
# calculate the daily sharpe ratio
daily_sharpe_ratio = avg_excess_return.div(sd_excess_return)

# annualize the sharpe ratio
annual_factor = np.sqrt(252)
annual_sharpe_ratio = daily_sharpe_ratio.mul(annual_factor)

# plot the annualized sharpe ratio
# ... YOUR CODE FOR TASK 10 HERE ...
annual_sharpe_ratio.plot.bar(title = 'Annualized Sharpe Ratio: Stocks vs S&P 500')

# %%
# Uncomment your choice.
buy_OSK = True
# buy_facebook = True
